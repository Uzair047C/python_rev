# %% [markdown]
# without inheritance instead of class we have to write all that code in pass that was writen in animal class

# %%
from Animal import Animals
class Dog(Animals):
        def speak(self):
            print("Dog : Woof!")

class Cat(Animals):
    pass
class Bird(Animals):
    pass

# %%
cat=Cat("kitty",2)
cat.eat()
# Out:
# kitty is eating whose age is 2.

# %%
dog=Dog("bango",4)
dog.speak()
dog.eat()
dog.sleep()
# Out:
# Dog : Woof!
# bango is eating whose age is 4.
# bango is sleeping whose age is 4.
