# %%
class Students:
    class_year=2026
    total_student=0
    def __init__(self,name,age):
        self.name=name
        self.age=age
        Students.total_students +=1
        
    print(f"class_year: {class_year} have {total_student} students")
