# %%
class school:
    enrollment_year = 2024
    section1 = "A"
    class Teacher:
        section_teacher = "Mr. Smith"
        def role(self):
            return "I am a teacher."
        
        def details_teacher(self,name):
            print(f"Enrollment Year: {school.enrollment_year}")
            print(f"Section Teacher: {self.section_teacher}")
    class Student:
        def role(self):
            return "I am a student."   
        def details_student(self,name):
            print(f"Enrollment Year: {school.enrollment_year}")
            print(f"Section 1: {school.section1}")
            print(f"Name: {name}")
class Ali(school.Student):
    pass
class Bob(school.Teacher):
    pass
ali = Ali()
bob = Bob()

# %%
ali.role()
s1=ali.details_student("Ali")
bob.role()
s2=bob.details_teacher("Bob")
# Out:
# Enrollment Year: 2024
# Section 1: A
# Name: Ali
# Enrollment Year: 2024
# Section Teacher: Mr. Smith
