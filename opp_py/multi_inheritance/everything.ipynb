# %%
class school:
    enrollment_year = 2024
    section1 = "A"
    section_teacher = "Mr. Smith"
    class Teacher:
        
        def role(self):
            return "I am a teacher."
        def __init__(self, name,section=school.section1):
            self.name = name
            self.section = section
        

    class Student:
        def role(self):
            return "I am a student."  
        def __init__(self, name, age,section=school.section1):
            self.name = name
            self.age = age 
            self.section = section

class Ali(school.Student):
    pass
class Bob(school.Teacher):
    pass

ali = Ali("Ali", 18,section=school.section1)
bob = Bob("bob", section=school.section_teacher)

# %%
print(ali.role())
print("my details are:")
print(f"Name: {ali.name}, Age: {ali.age}, Section: {ali.section}")
print(bob.role())
print("teacher details:")
print(f"Name: {bob.name}, Section: {bob.section}")
# Out:
# I am a student.
# my details are:
# Name: Ali, Age: 18, Section: A
# I am a teacher.
# teacher details:
# Name: bob, Section: Mr. Smith
