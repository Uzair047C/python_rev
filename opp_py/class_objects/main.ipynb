# %%
from student import Student

# %%
# from file import class

s1=Student("ALI",18,"ahmad","lahore")
s2=Student("Ahmi",14,"abd","lahore")
print(s1.name)
print(s1.roll_no)
print(s2.name)
print(s2.roll_no)
# Out:
# ALI
# 18
# Ahmi
# 14

# %% [markdown]
# # using method that was defined in class file

# %%
print (f"info of {s1.name} is:")
s1.info(remove )
print("_________________________")
print (f"info of {s2.name} is:")
s2.info()
# Out:
# info of ALI is:
# Name: ALI
# Roll No: 18
# Father Name: ahmad
# Address: lahore
# _________________________
# info of Ahmi is:
# Name: Ahmi
# Roll No: 14
# Father Name: abd
# Address: lahore
