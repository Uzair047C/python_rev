# %%
from abc import ABC,abstractmethod

# %% [markdown]
# # abstract class

# %%
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass
    def sleep(self):
        return "Zzz"

# %% [markdown]
# # abstract class

# %%
class Dog(Animal):
    def sound(self):
        return "Woof"
class Cat(Animal):
    def sound(self):
        return "Meow"

# %% [markdown]
# # object

# %%
cat=Cat()
dog=Dog()

# %%
print(f"Cat says: {cat.sound()}")
print(f"Cat is sleeping: {cat.sleep()}")
# Out:
# Cat says: Meow
# Cat is sleeping: Zzz

# %%
print(f"Dog says: {dog.sound()}")
print(f"Dog is sleeping: {dog.sleep()}")
# Out:
# Dog says: Woof
# Dog is sleeping: Zzz
